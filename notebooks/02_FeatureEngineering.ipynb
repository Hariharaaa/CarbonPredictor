# %% [markdown]
# # 02 — Feature Engineering
#
# Creates domain-informed features from clean data.
# All logic lives in `src/feature_engineering.py`.

# %%
import sys
sys.path.insert(0, '..')

import config as cfg
from src.feature_engineering import run_feature_engineering
from src.utils import load_csv

# %%
df = run_feature_engineering()
print(f'Engineered dataset: {df.shape}')
df.head()

# %%
# Inspect new features
new_cols = [c for c in df.columns if c not in ['company_name', 'ticker', 'reporting_year']]
df[new_cols].describe().round(3)
