# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# This notebook generates interactive Plotly charts for the Corporate Carbon Footprint Predictor.
#
# All chart logic lives in `src/eda.py` — this notebook imports and renders.

# %%
import sys
sys.path.insert(0, '..')

import config as cfg
from src.utils import load_csv
from src.eda import (
    plot_emissions_distribution,
    plot_correlation_heatmap,
    plot_sector_comparison,
    plot_revenue_vs_emissions,
    plot_assets_vs_emissions,
    plot_boxplots_by_sector,
    plot_missing_values,
    plot_feature_importance_preview,
    plot_pairplot,
)

# %%
df = load_csv(cfg.CLEAN_FILE)
print(f'Dataset: {df.shape[0]} rows × {df.shape[1]} columns')
df.head()

# %%
plot_emissions_distribution(df)

# %%
plot_correlation_heatmap(df)

# %%
plot_sector_comparison(df)

# %%
plot_revenue_vs_emissions(df)

# %%
plot_assets_vs_emissions(df)

# %%
plot_boxplots_by_sector(df)

# %%
plot_missing_values(df)

# %%
plot_feature_importance_preview(df)

# %%
plot_pairplot(df)
